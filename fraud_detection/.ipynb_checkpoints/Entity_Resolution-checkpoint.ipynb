# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import networkx as nx
import matplotlib.pyplot as plt

import os
# import pandas_profiling
datapath = 'C:\\Users\\luoyan011\\Desktop\\PersonalLearning\\GitHub\\dataset_2022'

pd.set_option('display.max_colwidth', 200)
# %matplotlib inline

# %%
datafile = '2021.11_WAVES-ACCESS-RECORDS.csv'
data=pd.read_csv(os.path.join(datapath, datafile))
print(data.shape)
data.head(3)
# Out:
# (4608, 27)
#   NAMELAST NAMEFIRST NAMEMID     UIN  BDGNBR ACCESS_TYPE               TOA  \
# 0  COLLINS    JOSHUA       A  HDG6DO     NaN          VA   11/2/2021 14:03
# 1  COLLINS    JOSHUA       A  HDG6DO     NaN          VA  11/16/2021 11:21
# 2  COLLINS    JOSHUA       A  HDG6DO     NaN          VA  11/17/2021 10:29
#
#      POA  TOD  POD  ...    LASTENTRYDATE TERMINAL_SUFFIX VISITEE_NAMELAST  \
# 0  VP005  NaN  NaN  ...  6/23/2021 17:47              GL             REED
# 1  VP005  NaN  NaN  ...  6/23/2021 17:47              GL             REED
# 2  VP005  NaN  NaN  ...  6/23/2021 17:47              GL             REED
#
#   VISITEE_NAMEFIRST  MEETING_LOC MEETING_ROOM CALLER_NAME_LAST  \
# 0              LEVI          VPR    RESIDENCE          GOODHUE
# 1              LEVI          VPR    RESIDENCE          GOODHUE
# 2              LEVI          VPR    RESIDENCE          GOODHUE
#
#   CALLER_NAME_FIRST CALLER_ROOM RELEASEDATE
# 0             KEVIN         NaN   3/11/2022
# 1             KEVIN         NaN   3/11/2022
# 2             KEVIN         NaN   3/11/2022
#
# [3 rows x 27 columns]

# %%
selected_columns = ['NAMELAST','NAMEFIRST', 'UIN','BDGNBR','NAMEMID', 'CALLER_NAME_LAST', 'CALLER_NAME_FIRST']
subset = data[selected_columns]
subset['CALLER_NAME'] = subset[['CALLER_NAME_LAST', 'CALLER_NAME_FIRST']].agg(' '.join, axis=1)
subset['VISITOR_NAME'] = subset[['NAMELAST', 'NAMEFIRST']].agg(' '.join, axis=1)
subset.sample(3)
# subset.to_csv(os.path.join(datapath, 'wh_visitor_clean_data.csv'))
# Out:
# C:\Users\luoyan011\.conda\envs\py37\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\luoyan011\.conda\envs\py37\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
#             NAMELAST NAMEFIRST     UIN  BDGNBR NAMEMID CALLER_NAME_LAST  \
# 2898            HEIL   KENNETH  U35083     NaN       E           POWELL
# 1171          WARDEN     JAMES  U34749     NaN       R            JOYCE
# 2384  PAGANSANMARTIN   ROLANDA  U35071     NaN       R           BUTLER
#
#      CALLER_NAME_FIRST     CALLER_NAME            VISITOR_NAME
# 2898           CHARLES  POWELL CHARLES            HEIL KENNETH
# 1171            MORGAN    JOYCE MORGAN            WARDEN JAMES
# 2384            NICOLE   BUTLER NICOLE  PAGANSANMARTIN ROLANDA

# %%
data[data.UIN=='U35560']
# Out:
#       NAMELAST NAMEFIRST NAMEMID     UIN    BDGNBR ACCESS_TYPE  \
# 3590  CASILLAS    CARMEN       N  U35560  182978.0          VA
# 3661    GUZMAN    CORTEZ       C  U35560  179535.0          VA
# 3662    GUZMAN      CRUZ       C  U35560  178325.0          VA
# 3663    GUZMAN    JAVIER       R  U35560  185882.0          VA
#
#                  TOA  POA  TOD  POD  ...   LASTENTRYDATE TERMINAL_SUFFIX  \
# 3590  11/19/21 13:53  NaN  NaN  NaN  ...  11/19/21 10:13              TI
# 3661  11/19/21 13:54  NaN  NaN  NaN  ...  11/19/21 10:13              TI
# 3662  11/19/21 13:54  NaN  NaN  NaN  ...  11/19/21 10:13              TI
# 3663  11/19/21 13:47  NaN  NaN  NaN  ...  11/19/21 10:13              TI
#
#      VISITEE_NAMELAST VISITEE_NAMEFIRST  MEETING_LOC MEETING_ROOM  \
# 3590           Murray              Tara           WH   Rose Garde
# 3661           Murray              Tara           WH   Rose Garde
# 3662           Murray              Tara           WH   Rose Garde
# 3663           Murray              Tara           WH   Rose Garde
#
#      CALLER_NAME_LAST CALLER_NAME_FIRST CALLER_ROOM RELEASEDATE
# 3590             ISEN            THOMAS         NaN   3/11/2022
# 3661             ISEN            THOMAS         NaN   3/11/2022
# 3662             ISEN            THOMAS         NaN   3/11/2022
# 3663             ISEN            THOMAS         NaN   3/11/2022
#
# [4 rows x 27 columns]

# %%
def get_G(data, edge_nodes):
    edge_list = []
    for edge in edge_nodes:
        edge_list += list(zip(data[edge[0]], data[edge[1]]))
    return(edge_list)
def create_multi_graph(data, node_list):
    BG = nx.MultiGraph()
    for nodes in node_list:
        node1 = list(data[nodes[0]].unique())
        node2 = list(data[nodes[1]].unique())

        BG.add_nodes_from(node1, bipartite=0, _type=nodes[0])
        BG.add_nodes_from(node2, bipartite=1, _type=nodes[1])

        edges = get_G(data, [nodes])
        BG.add_edges_from(edges)
    
    labels = dict((n, "(" + n + "," + d['_type'] + ")") for n,d in BG.nodes(data=True))


    plt.figure(figsize=(16, 12), dpi=80)
    edges = BG.edges()
#     nx.draw(BG, pos=nx.circular_layout(BG), labels=labels)
#     nx.draw(BG, pos=nx.shell_layout(BG), labels=labels)
    nx.draw(BG, pos=nx.random_layout(BG), labels=labels)
#     nx.draw(BG, pos=nx.draw_planar(BG), labels=labels)
    return(BG)

customized_edges = [['NAMELAST','VISITOR_NAME'], ['VISITOR_NAME', 'CALLER_NAME'], ['VISITOR_NAME','NAMEMID'], 
                    ['NAMEFIRST','VISITOR_NAME']]
testG = create_multi_graph(subset[subset.UIN.isin(['U35560','U35083'])], customized_edges)

# %%
nx.degree_centrality(testG)
# Out:
# {'HEIL': 0.04,
#  'HYATT': 0.04,
#  'WARNICK': 0.04,
#  'CASILLAS': 0.04,
#  'GUZMAN': 0.12,
#  'HEIL KENNETH': 0.16,
#  'HYATT RUSTY': 0.16,
#  'WARNICK JOSEPH': 0.16,
#  'CASILLAS CARMEN': 0.16,
#  'GUZMAN CORTEZ': 0.16,
#  'GUZMAN CRUZ': 0.16,
#  'GUZMAN JAVIER': 0.16,
#  'POWELL CHARLES': 0.12,
#  'ISEN THOMAS': 0.16,
#  'E': 0.08,
#  'M': 0.04,
#  'N': 0.04,
#  'C': 0.08,
#  'R': 0.04,
#  'KENNETH': 0.04,
#  'RUSTY': 0.04,
#  'JOSEPH': 0.04,
#  'CARMEN': 0.04,
#  'CORTEZ': 0.04,
#  'CRUZ': 0.04,
#  'JAVIER': 0.04}

# %%
from networkx.algorithms.community.centrality import girvan_newman
communities = girvan_newman(testG)
 
node_groups = []
for com in next(communities):
    node_groups.append(list(com))

print(node_groups)
# Out:
# [['KENNETH', 'WARNICK JOSEPH', 'HYATT', 'RUSTY', 'JOSEPH', 'M', 'POWELL CHARLES', 'WARNICK', 'HEIL', 'HEIL KENNETH', 'HYATT RUSTY', 'E'], ['N', 'CASILLAS CARMEN', 'CARMEN', 'CASILLAS'], ['C', 'GUZMAN JAVIER', 'CORTEZ', 'R', 'GUZMAN CRUZ', 'CRUZ', 'GUZMAN', 'GUZMAN CORTEZ', 'ISEN THOMAS', 'JAVIER']]

# %%
nx.group_betweenness_centrality(testG, node_groups[2])
# Out:
# 2.3684757858670006e-16
